# %% [markdown]
# # Vector DB
#
# In this notebook, we use a containerized version of Chroma DB. To set up, you will need the following:
#
# 1. Install [Docker Desktop](https://www.docker.com/products/docker-desktop/) by following the link and Download Docker Desktop for your operating system.
# 2. In a terminal window, navigate to the folder ./05_src/chromadb/. For example, on Windows, you would use `cd .\05_src\chromadb`.
# 3. Run the command `docker compose up -d`, which will start the Chroma DB server.

# %% [markdown]
# ## Downloading Batch Results
#
# In the previous notebook, we had created batch processes. We will start by consulting the status of our batch processes by identifying them throught their descriptions.

# %%
# %load_ext dotenv
# %dotenv ../../05_src/.secrets

# %%
batch_description = 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54'

# %%
from openai import OpenAI
import os

# client = OpenAI(base_url='https://k7uffyg03f.execute-api.us-east-1.amazonaws.com/prod/openai/v1', 
#                 default_headers={"x-api-key": os.getenv('API_GATEWAY_KEY')})
client = OpenAI()

batch_processes = client.batches.list().to_dict()
batch_info= [
    {'batch_id': batch['id'],
     'description': batch['metadata']['description'],
    'status': batch['status'],
    'request_counts': batch['request_counts'],
    'output_file_id': batch['output_file_id'],
    'input_file_id': batch['input_file_id']}
            for batch in batch_processes['data'] if batch['metadata']['description'] == batch_description
    ]
batch_info
# Out:
# [{'batch_id': 'batch_698e289a55f881908160dc50245a838a',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-MCwdvNLhEq61ov9ZKmbqgn',
#   'input_file_id': 'file-MjzJVjeK4guNZ7fWSiiAby'},
#  {'batch_id': 'batch_698e289a1db881909344f9c3abd0f6d6',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-151NMxkjfoCfJknTFHrg3u',
#   'input_file_id': 'file-1EiWYszPmEoUNm9AfTfEAA'},
#  {'batch_id': 'batch_698e2899f0608190b8852c482cf342aa',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-1Ly9PDhvWQ27JoogSmeCuN',
#   'input_file_id': 'file-ECzZ2QZCd1tmE8ecZJtB8t'},
#  {'batch_id': 'batch_698e28999c30819092543b7b214b8bbc',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-EFiZ4Evy2zCoqCXhcSBaAr',
#   'input_file_id': 'file-Q72yuafiq76nQU1yQm6wRo'},
#  {'batch_id': 'batch_698e28996e088190bb2eee7c1c91b822',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-K3bdau4EH5iTR6paeCeopB',
#   'input_file_id': 'file-3AgobaBddnQstnvy7u65Hv'},
#  {'batch_id': 'batch_698e289936788190a2931e698e89c1b6',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 346, 'failed': 0, 'total': 346},
#   'output_file_id': 'file-3wKQEpQdobu8uJPCyx7Gm1',
#   'input_file_id': 'file-R9nVUBeHKpSaTPg8hUN3LC'},
#  {'batch_id': 'batch_698e2898ffdc8190878cd36e663b08b8',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-Ht7JxjbAJ6aTmPuahdXraX',
#   'input_file_id': 'file-1NhhgYaoWu2iexgNmsBhCD'},
#  {'batch_id': 'batch_698e2898cbb881908ed73ec4bfdaaa92',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-FsAxDxixURzmC5dfsJ8AeZ',
#   'input_file_id': 'file-JoULMLT6UWri2B67cRRmMo'},
#  {'batch_id': 'batch_698e28989fdc819083dc64e8e69ea7c4',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-2U6Umt8ZRgwqNsGEGeuJFE',
#   'input_file_id': 'file-YDb6JK5VYmkpLGRCSy7JsL'},
#  {'batch_id': 'batch_698e289867808190b68386bfbb65d501',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-3Mj41hqBj22kLWycD1Z1tA',
#   'input_file_id': 'file-T6Ye1QS5GLwB7WVn1S9fRP'},
#  {'batch_id': 'batch_698e2898304c8190909c1f5c3bf745f5',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-GVrdjDLFyQsag5K1QTDRE9',
#   'input_file_id': 'file-BpdhbPTGqb1rgX2m3EfkoG'},
#  {'batch_id': 'batch_698e2897f8188190a00447b1074e9448',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-Jwe15ETGM8ZBXf8dXS9e9h',
#   'input_file_id': 'file-1YEbRTdsqk8ysGycPoc1oi'},
#  {'batch_id': 'batch_698e2897c9c0819088461df003b0174d',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-3d1AVsTpsZ2f6bDX16pXhG',
#   'input_file_id': 'file-Lh2f5XKoRMj9NN4Yiu9rPR'},
#  {'batch_id': 'batch_698e289795b481909b782c5f21e293da',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-CT4i2WfnVaBjiN3v5gmrV6',
#   'input_file_id': 'file-KdHmeco2WqwoMJPZNtmtTm'},
#  {'batch_id': 'batch_698e289761fc8190bc06c374d2efc43c',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-F8uT5oqVyjWvZNNcjZCjQ1',
#   'input_file_id': 'file-FKg33gaysUCaJzpwHwntji'},
#  {'batch_id': 'batch_698e2897159081909eb108403a94716e',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-Ki3KaiELqLfJYD8cyJ7x8c',
#   'input_file_id': 'file-AhHQKPq6pJcEv6qzBGdLEZ'},
#  {'batch_id': 'batch_698e2896bfbc819096b08793d475b9c4',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-QCpq6d5tNibGcuM7rBdxxc',
#   'input_file_id': 'file-ByRmtyzqZKBAeYZ1wZ2XaT'},
#  {'batch_id': 'batch_698e289693f48190ac93ce2b0fa773db',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-1c59X75jBcKemVMGpEiMyv',
#   'input_file_id': 'file-7oPdhLFUdZFD3DUZ3HTjNR'},
#  {'batch_id': 'batch_698e2896667c81909ba3f4dafb47db12',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-QLGJpafPWWP5RYH57YFqLb',
#   'input_file_id': 'file-Wf7FQtqTnAahPP6f9pGAHe'},
#  {'batch_id': 'batch_698e2896310881909aec239eae7f9b91',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-C7TchX5f1AWGsmKntYZxSh',
#   'input_file_id': 'file-HM1NyW2gUHEFvHX6Hi8Qb3'}]

# %%
batch_processes['data']
# Out:
# [{'id': 'batch_698e289a55f881908160dc50245a838a',
#   'completion_window': '24h',
#   'created_at': 1770924186,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-MjzJVjeK4guNZ7fWSiiAby',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924342,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010586,
#   'failed_at': None,
#   'finalizing_at': 1770924285,
#   'in_progress_at': 1770924187,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-MCwdvNLhEq61ov9ZKmbqgn',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 371224,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 371224}},
#  {'id': 'batch_698e289a1db881909344f9c3abd0f6d6',
#   'completion_window': '24h',
#   'created_at': 1770924186,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-1EiWYszPmEoUNm9AfTfEAA',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924388,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010586,
#   'failed_at': None,
#   'finalizing_at': 1770924290,
#   'in_progress_at': 1770924187,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-151NMxkjfoCfJknTFHrg3u',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 374474,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 374474}},
#  {'id': 'batch_698e2899f0608190b8852c482cf342aa',
#   'completion_window': '24h',
#   'created_at': 1770924185,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-ECzZ2QZCd1tmE8ecZJtB8t',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924499,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010585,
#   'failed_at': None,
#   'finalizing_at': 1770924346,
#   'in_progress_at': 1770924187,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-1Ly9PDhvWQ27JoogSmeCuN',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 374037,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 374037}},
#  {'id': 'batch_698e28999c30819092543b7b214b8bbc',
#   'completion_window': '24h',
#   'created_at': 1770924185,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-Q72yuafiq76nQU1yQm6wRo',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924414,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010585,
#   'failed_at': None,
#   'finalizing_at': 1770924304,
#   'in_progress_at': 1770924187,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-EFiZ4Evy2zCoqCXhcSBaAr',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 370063,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 370063}},
#  {'id': 'batch_698e28996e088190bb2eee7c1c91b822',
#   'completion_window': '24h',
#   'created_at': 1770924185,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-3AgobaBddnQstnvy7u65Hv',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924480,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010585,
#   'failed_at': None,
#   'finalizing_at': 1770924330,
#   'in_progress_at': 1770924186,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-K3bdau4EH5iTR6paeCeopB',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 369661,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 369661}},
#  {'id': 'batch_698e289936788190a2931e698e89c1b6',
#   'completion_window': '24h',
#   'created_at': 1770924185,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-R9nVUBeHKpSaTPg8hUN3LC',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924309,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010585,
#   'failed_at': None,
#   'finalizing_at': 1770924288,
#   'in_progress_at': 1770924186,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-3wKQEpQdobu8uJPCyx7Gm1',
#   'request_counts': {'completed': 346, 'failed': 0, 'total': 346},
#   'usage': {'input_tokens': 127131,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 127131}},
#  {'id': 'batch_698e2898ffdc8190878cd36e663b08b8',
#   'completion_window': '24h',
#   'created_at': 1770924184,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-1NhhgYaoWu2iexgNmsBhCD',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770925220,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010584,
#   'failed_at': None,
#   'finalizing_at': 1770925159,
#   'in_progress_at': 1770924186,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-Ht7JxjbAJ6aTmPuahdXraX',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 366349,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 366349}},
#  {'id': 'batch_698e2898cbb881908ed73ec4bfdaaa92',
#   'completion_window': '24h',
#   'created_at': 1770924184,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-JoULMLT6UWri2B67cRRmMo',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924367,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010584,
#   'failed_at': None,
#   'finalizing_at': 1770924285,
#   'in_progress_at': 1770924185,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-FsAxDxixURzmC5dfsJ8AeZ',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 384204,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 384204}},
#  {'id': 'batch_698e28989fdc819083dc64e8e69ea7c4',
#   'completion_window': '24h',
#   'created_at': 1770924184,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-YDb6JK5VYmkpLGRCSy7JsL',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924315,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010584,
#   'failed_at': None,
#   'finalizing_at': 1770924265,
#   'in_progress_at': 1770924185,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-2U6Umt8ZRgwqNsGEGeuJFE',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 380948,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 380948}},
#  {'id': 'batch_698e289867808190b68386bfbb65d501',
#   'completion_window': '24h',
#   'created_at': 1770924184,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-T6Ye1QS5GLwB7WVn1S9fRP',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924371,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010584,
#   'failed_at': None,
#   'finalizing_at': 1770924298,
#   'in_progress_at': 1770924185,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-3Mj41hqBj22kLWycD1Z1tA',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 391527,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 391527}},
#  {'id': 'batch_698e2898304c8190909c1f5c3bf745f5',
#   'completion_window': '24h',
#   'created_at': 1770924184,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-BpdhbPTGqb1rgX2m3EfkoG',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924411,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010584,
#   'failed_at': None,
#   'finalizing_at': 1770924302,
#   'in_progress_at': 1770924185,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-GVrdjDLFyQsag5K1QTDRE9',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 380349,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 380349}},
#  {'id': 'batch_698e2897f8188190a00447b1074e9448',
#   'completion_window': '24h',
#   'created_at': 1770924183,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-1YEbRTdsqk8ysGycPoc1oi',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924342,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010583,
#   'failed_at': None,
#   'finalizing_at': 1770924294,
#   'in_progress_at': 1770924185,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-Jwe15ETGM8ZBXf8dXS9e9h',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 380610,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 380610}},
#  {'id': 'batch_698e2897c9c0819088461df003b0174d',
#   'completion_window': '24h',
#   'created_at': 1770924183,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-Lh2f5XKoRMj9NN4Yiu9rPR',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924333,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010583,
#   'failed_at': None,
#   'finalizing_at': 1770924285,
#   'in_progress_at': 1770924184,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-3d1AVsTpsZ2f6bDX16pXhG',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 381430,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 381430}},
#  {'id': 'batch_698e289795b481909b782c5f21e293da',
#   'completion_window': '24h',
#   'created_at': 1770924183,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-KdHmeco2WqwoMJPZNtmtTm',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924454,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010583,
#   'failed_at': None,
#   'finalizing_at': 1770924354,
#   'in_progress_at': 1770924184,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-CT4i2WfnVaBjiN3v5gmrV6',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 376074,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 376074}},
#  {'id': 'batch_698e289761fc8190bc06c374d2efc43c',
#   'completion_window': '24h',
#   'created_at': 1770924183,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-FKg33gaysUCaJzpwHwntji',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924447,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010583,
#   'failed_at': None,
#   'finalizing_at': 1770924346,
#   'in_progress_at': 1770924184,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-F8uT5oqVyjWvZNNcjZCjQ1',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 380724,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 380724}},
#  {'id': 'batch_698e2897159081909eb108403a94716e',
#   'completion_window': '24h',
#   'created_at': 1770924183,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-AhHQKPq6pJcEv6qzBGdLEZ',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924418,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010583,
#   'failed_at': None,
#   'finalizing_at': 1770924361,
#   'in_progress_at': 1770924244,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-Ki3KaiELqLfJYD8cyJ7x8c',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 367570,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 367570}},
#  {'id': 'batch_698e2896bfbc819096b08793d475b9c4',
#   'completion_window': '24h',
#   'created_at': 1770924182,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-ByRmtyzqZKBAeYZ1wZ2XaT',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924486,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010582,
#   'failed_at': None,
#   'finalizing_at': 1770924423,
#   'in_progress_at': 1770924243,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-QCpq6d5tNibGcuM7rBdxxc',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 378376,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 378376}},
#  {'id': 'batch_698e289693f48190ac93ce2b0fa773db',
#   'completion_window': '24h',
#   'created_at': 1770924182,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-7oPdhLFUdZFD3DUZ3HTjNR',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924337,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010582,
#   'failed_at': None,
#   'finalizing_at': 1770924273,
#   'in_progress_at': 1770924183,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-1c59X75jBcKemVMGpEiMyv',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 375237,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 375237}},
#  {'id': 'batch_698e2896667c81909ba3f4dafb47db12',
#   'completion_window': '24h',
#   'created_at': 1770924182,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-Wf7FQtqTnAahPP6f9pGAHe',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770924565,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010582,
#   'failed_at': None,
#   'finalizing_at': 1770924412,
#   'in_progress_at': 1770924183,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-QLGJpafPWWP5RYH57YFqLb',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 353061,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 353061}},
#  {'id': 'batch_698e2896310881909aec239eae7f9b91',
#   'completion_window': '24h',
#   'created_at': 1770924182,
#   'endpoint': '/v1/embeddings',
#   'input_file_id': 'file-HM1NyW2gUHEFvHX6Hi8Qb3',
#   'object': 'batch',
#   'status': 'completed',
#   'cancelled_at': None,
#   'cancelling_at': None,
#   'completed_at': 1770931522,
#   'error_file_id': None,
#   'errors': None,
#   'expired_at': None,
#   'expires_at': 1771010582,
#   'failed_at': None,
#   'finalizing_at': 1770931446,
#   'in_progress_at': 1770924183,
#   'metadata': {'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#    'timestamp': '2026-02-12 14:22:54'},
#   'model': 'text-embedding-3-small',
#   'output_file_id': 'file-C7TchX5f1AWGsmKntYZxSh',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'usage': {'input_tokens': 363376,
#    'input_tokens_details': {'cached_tokens': 0},
#    'output_tokens': 0,
#    'output_tokens_details': {'reasoning_tokens': 0},
#    'total_tokens': 363376}}]

# %% [markdown]
# When the status of the batches is complete, we can query the `output_file_id` where their results will be stored.
#
# More generally, we will require the original text and the embeddings of that original text mapped through the `custom_id`.

# %%
batch_complete = [
    batch  for batch in batch_info if batch['status'] == 'completed'
]
batch_complete
# Out:
# [{'batch_id': 'batch_698e289a55f881908160dc50245a838a',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-MCwdvNLhEq61ov9ZKmbqgn',
#   'input_file_id': 'file-MjzJVjeK4guNZ7fWSiiAby'},
#  {'batch_id': 'batch_698e289a1db881909344f9c3abd0f6d6',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-151NMxkjfoCfJknTFHrg3u',
#   'input_file_id': 'file-1EiWYszPmEoUNm9AfTfEAA'},
#  {'batch_id': 'batch_698e2899f0608190b8852c482cf342aa',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-1Ly9PDhvWQ27JoogSmeCuN',
#   'input_file_id': 'file-ECzZ2QZCd1tmE8ecZJtB8t'},
#  {'batch_id': 'batch_698e28999c30819092543b7b214b8bbc',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-EFiZ4Evy2zCoqCXhcSBaAr',
#   'input_file_id': 'file-Q72yuafiq76nQU1yQm6wRo'},
#  {'batch_id': 'batch_698e28996e088190bb2eee7c1c91b822',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-K3bdau4EH5iTR6paeCeopB',
#   'input_file_id': 'file-3AgobaBddnQstnvy7u65Hv'},
#  {'batch_id': 'batch_698e289936788190a2931e698e89c1b6',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 346, 'failed': 0, 'total': 346},
#   'output_file_id': 'file-3wKQEpQdobu8uJPCyx7Gm1',
#   'input_file_id': 'file-R9nVUBeHKpSaTPg8hUN3LC'},
#  {'batch_id': 'batch_698e2898ffdc8190878cd36e663b08b8',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-Ht7JxjbAJ6aTmPuahdXraX',
#   'input_file_id': 'file-1NhhgYaoWu2iexgNmsBhCD'},
#  {'batch_id': 'batch_698e2898cbb881908ed73ec4bfdaaa92',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-FsAxDxixURzmC5dfsJ8AeZ',
#   'input_file_id': 'file-JoULMLT6UWri2B67cRRmMo'},
#  {'batch_id': 'batch_698e28989fdc819083dc64e8e69ea7c4',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-2U6Umt8ZRgwqNsGEGeuJFE',
#   'input_file_id': 'file-YDb6JK5VYmkpLGRCSy7JsL'},
#  {'batch_id': 'batch_698e289867808190b68386bfbb65d501',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-3Mj41hqBj22kLWycD1Z1tA',
#   'input_file_id': 'file-T6Ye1QS5GLwB7WVn1S9fRP'},
#  {'batch_id': 'batch_698e2898304c8190909c1f5c3bf745f5',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-GVrdjDLFyQsag5K1QTDRE9',
#   'input_file_id': 'file-BpdhbPTGqb1rgX2m3EfkoG'},
#  {'batch_id': 'batch_698e2897f8188190a00447b1074e9448',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-Jwe15ETGM8ZBXf8dXS9e9h',
#   'input_file_id': 'file-1YEbRTdsqk8ysGycPoc1oi'},
#  {'batch_id': 'batch_698e2897c9c0819088461df003b0174d',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-3d1AVsTpsZ2f6bDX16pXhG',
#   'input_file_id': 'file-Lh2f5XKoRMj9NN4Yiu9rPR'},
#  {'batch_id': 'batch_698e289795b481909b782c5f21e293da',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-CT4i2WfnVaBjiN3v5gmrV6',
#   'input_file_id': 'file-KdHmeco2WqwoMJPZNtmtTm'},
#  {'batch_id': 'batch_698e289761fc8190bc06c374d2efc43c',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-F8uT5oqVyjWvZNNcjZCjQ1',
#   'input_file_id': 'file-FKg33gaysUCaJzpwHwntji'},
#  {'batch_id': 'batch_698e2897159081909eb108403a94716e',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-Ki3KaiELqLfJYD8cyJ7x8c',
#   'input_file_id': 'file-AhHQKPq6pJcEv6qzBGdLEZ'},
#  {'batch_id': 'batch_698e2896bfbc819096b08793d475b9c4',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-QCpq6d5tNibGcuM7rBdxxc',
#   'input_file_id': 'file-ByRmtyzqZKBAeYZ1wZ2XaT'},
#  {'batch_id': 'batch_698e289693f48190ac93ce2b0fa773db',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-1c59X75jBcKemVMGpEiMyv',
#   'input_file_id': 'file-7oPdhLFUdZFD3DUZ3HTjNR'},
#  {'batch_id': 'batch_698e2896667c81909ba3f4dafb47db12',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-QLGJpafPWWP5RYH57YFqLb',
#   'input_file_id': 'file-Wf7FQtqTnAahPP6f9pGAHe'},
#  {'batch_id': 'batch_698e2896310881909aec239eae7f9b91',
#   'description': 'Pitchfork reviews content embeddings (jcalderon_20260212) 2026-02-12 14:22:54',
#   'status': 'completed',
#   'request_counts': {'completed': 1000, 'failed': 0, 'total': 1000},
#   'output_file_id': 'file-C7TchX5f1AWGsmKntYZxSh',
#   'input_file_id': 'file-HM1NyW2gUHEFvHX6Hi8Qb3'}]

# %% [markdown]
# Before we download all results, examine the response of the file API:

# %%
response = client.files.content(batch_complete[0]['output_file_id'])
text_response = response.text
lines = text_response.split('\n')
print(lines[0])
# Out:
# {"id": "batch_req_698e28fdf7448190841d0b9fc9d5dfe8", "custom_id": "19643_2861_1807", "response": {"status_code": 200, "request_id": "51171700-6e23-42c1-a750-664697344570", "body": {"object": "list", "data": [{"object": "embedding", "index": 0, "embedding": [0.00030744667, 0.009419799, -0.00026936, 8.209572e-06, -0.02060168, -0.01085149, 0.009588665, 0.067194074, 0.0143829975, 0.0019346196, -0.010513758, -0.025359303, -0.023509117, 0.014104001, -0.034683656, 0.039646853, -0.008854464, -0.012914595, -0.0016574587, -0.028751312, 0.016284578, 0.009045356, -0.01355335, 0.027914321, -0.012995358, -0.015330117, -0.047165073, -0.0032451684, 0.049984403, 0.017429931, -0.020777889, -0.022525286, 0.030307816, 0.020058371, 0.002826674, -0.023641272, -0.014639968, 0.004368496, -0.044257637, 0.013090804, 0.030748338, -0.006453627, 0.01866339, -0.012356603, 0.02582919, 0.01303941, -0.012988016, 0.012261157, 0.015917478, 0.07594575, 0.004541033, 0.04463942, -0.018604653, 0.04690076, 0.023274172, -0.019970268, -0.012158369, -0.020381419, -0.00146106, 0.022202238, 0.0023843178, -0.010535784, 0.034096293, 0.03292157, -0.030630866, 0.00094069506, -0.042789236, 0.00037581913, 0.014874912, 0.0058332267, 0.020777889, 0.013450562, -0.01647547, -0.014037923, -0.019588
def get_text_and_embeddings(batch):
    embedding_lines =  get_content_from_file(batch, 'output_file_id')
    text_lines = get_content_from_file(batch, 'input_file_id')
    return embedding_lines, text_lines

def get_content_from_file(batch, key):
    file = client.files.content(batch[key])
    text = file.text
    lines = text.split('\n')
    content_lines = [json.loads(line) for line in lines if line.strip()]
    return content_lines

# %% [markdown]
# Notice that the response is also a .jsonl file. Therefore, we can process it line-by-line and use the `custom_id` to map to the original document chunk.
#
# The function below:
#
# - Creates a dictionary, `text_dict`, with keys given by each `custom_id` and value equal to the text.
# - Iterate over all embedding items and use the dictionary defined above to map the embeddings to their input text.

# %%
def create_chroma_inputs(embedding_lines, text_lines):
    chroma_inputs = []
    text_dict = {item['custom_id']: item['body']['input'] for item in text_lines}
    for embed_item in embedding_lines:
        custom_id = embed_item['custom_id']
        text = text_dict.get(custom_id, "")
        chroma_input = {
            'id': embed_item['custom_id'],
            'embedding': embed_item['response']['body']['data'][0]['embedding'],
            'text': text
        }
        chroma_inputs.append(chroma_input)
    return chroma_inputs

# %% [markdown]
# A couple of functions to control the logic flow:

# %%
from tqdm import tqdm

def process_batch_for_chromadb(batch):
    embedding_lines, text_lines = get_text_and_embeddings(batch)
    chroma_inputs = create_chroma_inputs(embedding_lines, text_lines)
    return chroma_inputs

def process_batches_for_chromadb(batches):
    all_chroma_inputs = []
    for batch in tqdm(batches, desc="Processing batches"):
        chroma_inputs = process_batch_for_chromadb(batch)
        all_chroma_inputs.extend(chroma_inputs)
    return all_chroma_inputs

# %% [markdown]
# Now, we can create our input dictionaries.

# %%
chroma_inputs = process_batches_for_chromadb(batch_complete)
# Out:
# Processing batches: 100%|██████████| 20/20 [00:55<00:00,  2.77s/it]

# %%
chroma_inputs[1]
# Out:
# {'id': '19643_2861_3609',
#  'embedding': [-0.008924569,
#   -0.029277397,
#   -0.02974355,
#   0.03888616,
#   0.0344953,
#   0.026931597,
#   -0.011947043,
#   0.054314308,
#   0.0075223516,
#   0.0054547386,
#   -0.00020629137,
#   -0.019307744,
#   -0.022239996,
#   0.0013232722,
#   -0.040961288,
#   0.017864175,
#   -0.02888643,
#   -0.037953854,
#   0.00667651,
#   -0.008022338,
#   0.002039418,
#   0.0021427989,
#   -0.039126754,
#   0.026826337,
#   -0.020119753,
#   -0.008225339,
#   0.0030525483,
#   0.010165136,
#   0.045412295,
#   0.017849138,
#   -0.016044676,
#   -0.034134407,
#   0.03491634,
#   0.0046803234,
#   -0.006755455,
#   -0.029442806,
#   -0.043698058,
#   0.031337492,
#   -0.009706503,
#   -0.0008575894,
#   0.04460029,
#   -0.029908959,
#   0.02467602,
#   -0.013398131,
#   0.004368302,
#   -0.014661254,
#   -0.05659996,
#   -0.0030619467,
#   0.04357776,
#   0.0639381,
#   -0.014112397,
#   0.050976053,
#   -0.038104225,
#   0.03669073,
#   0.0146236615,
#   -0.009947097,
#   -0.014127434,
#   -0.01201471,
#   0.0014454493,
#   0.00072695385,
#   0.011413223,
#   0.023036966,
#   0.008135117,
#   0.03533738,
#   -0.005890817,
#   -0.02392416,
#   ...],
#  'text': 'in her Y\'all think I\'m talkin\' about women? I\'m talkin\' about God, or a higher being, whatever you believe in"). "Lifted" trots out a snapping, Cobblestone Jazzy synth-and-drum-machine jam while Diddy reels off vocoded nonsequiturs. It doesn\'t feel as fresh as "Broken Windows," but it\'s probably the album\'s standout club jam, setting aside "Tourist Trap", a minimal-house anthem that samples Diddy-Dirty Money\'s "Hello Good Morning" and was a big deal in clubs way back in 2011."Angels," with its watery wibbles, psychedelic guitar and loping disco beat, sounds like a confused fusion between Cocteau Twins, Pink Floyd, and Soul Clap; "I Hear Her Calling Me" is similarly bathetic and even more unfocused, with piano noodling tangled up with dub delay, trap hi-hats, and about 17 layers of background vocoder. And so it goes, all the way through to the closing "Terminal K", an altered-states ode that sounds like Ricardo Villalobos clumsily remixing Dead Can Dance. (No prizes for guessing what that letter stands for, given that back in March, Diddy confessed to listening-party attendees that they considered calling the album Ketamine.)Diddy\'s interest in dance music actually goes back more than a decade. Way back in 2004, he enlisted Stuart Price, Nellee Hooper, and Erick Morillo, among others, to make a project called Divided Soul, an Ibiza-inspired record that got derailed when Ibiza proved a little too inspiring. ("We rented a house [in Ibiza], and we started," Diddy told Pete Tong at the IMS Engage conference in April. "We were supposed to record for seven days, but once I went out to the clubs I didn\'t return back to the house for seven days.") A few years later he discovered DC-10\'s Circoloco parties, where he brandished a miniature vuvuzela and mingled with the sweaty, sunglasses-wearing masses to the strains of DJs like Perlon\'s Zip.So it\'s not that surprising that Diddy would gravitate towards the deeper, more ruminative strains of European tech-house, rather than'}

# %%
with open('../../05_src/documents/chroma_inputs.jsonl', 'w') as f:
    for ci in tqdm(chroma_inputs):
        json_str = json.dumps(ci)
        f.write(json_str + '\n')
# Out:
# 100%|██████████| 19346/19346 [00:16<00:00, 1155.26it/s]

# %% [markdown]
# # Load Embeddings to Chroma

# %%
chroma_inputs = []
with open('../../05_src/documents/chroma_inputs.jsonl', 'r') as f:
    for line in f:
        chroma_inputs.append(json.loads(line.strip()))

# %%
import chromadb
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction
import os


def setup_collection(chroma_url:str="http://localhost:8000",
                     collection_name: str = "pitchfork_reviews"):
    chroma_client = chromadb.HttpClient(host=chroma_url)
    collections = chroma_client.list_collections()
    if collection_name in [col.name for col in collections]:
        chroma_client.delete_collection(name=collection_name)

    collection = chroma_client.create_collection(
        name=collection_name,
        embedding_function=OpenAIEmbeddingFunction(
            api_key = os.getenv("OPENAI_API_KEY"),
            model_name="text-embedding-3-small")
        )
    return collection

def load_embeddings_to_db(chroma_inputs:list[dict], 
                          collection_name:str,
                          chroma_url:str="http://localhost:8000",
                          batch_size:int= 1000
                          ):

    
    collection = setup_collection(chroma_url=chroma_url, collection_name=collection_name)

    for i in tqdm(range(0, len(chroma_inputs), batch_size)):
        batch = chroma_inputs[i:i + batch_size]
        collection.add(
            documents=[item['text'] for item in batch],
            embeddings=[item['embedding'] for item in batch],
            ids=[item['id'] for item in batch]
        )

# %%
vector_db_client_url:str="http://localhost:8000"
load_embeddings_to_db(chroma_inputs=chroma_inputs,
                      collection_name="pitchfork_reviews",
                      chroma_url=vector_db_client_url, 
                      batch_size=1000)
# Out:
# 100%|██████████| 20/20 [00:54<00:00,  2.70s/it]

# %% [markdown]
# # Additional Details
#
# We will use a simple database to store additional details about the reviews. In this case, we load the jsonl files, and use pandas to create a few tables in a sql database. The connection string to the database is included in the .secrets file.

# %%
import json

def load_jsonl(file:str):
    data = []
    with open(file, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                data.append(json.loads(line))
    return data

# %%
import pandas as pd
import sqlalchemy as sa
import os

doc_folder = "../../05_src/documents/"
tables = ["artists", "reviews", "labels", "genres"]

def upload_tables_to_sql(tables:list[str], doc_folder:str):
    engine = sa.create_engine(os.getenv("SQL_URL"))
    for table_name in tables:
        file_path = os.path.join(doc_folder, f"pitchfork_{table_name}.jsonl")
        data = load_jsonl(file_path)
        df = pd.DataFrame(data)
        with engine.connect() as conn:
            df.to_sql(table_name, conn, if_exists='replace', index=False)
        print(f"Loaded {df.shape} records from {file_path}")

upload_tables_to_sql(tables=tables, doc_folder=doc_folder)
# Out:
# Loaded (18831, 2) records from ../../05_src/documents/pitchfork_artists.jsonl
# Loaded (18393, 13) records from ../../05_src/documents/pitchfork_reviews.jsonl
# Loaded (20190, 2) records from ../../05_src/documents/pitchfork_labels.jsonl
# Loaded (22680, 2) records from ../../05_src/documents/pitchfork_genres.jsonl

# %%
def additional_details(review_id:str):
    import sqlalchemy as sa
    import pandas as pd
    import os

    engine = sa.create_engine(os.getenv("SQL_URL"))
    query = f"""
    SELECT r.reviewid,
		r.title,
		r.artist,
		r.score,
		g.genre
    FROM reviews AS r
    LEFT JOIN genres as g
	    ON r.reviewid = g.reviewid
    WHERE r.reviewid = '{review_id}'
    """
    with engine.connect() as conn:
        result = pd.read_sql(query, conn)
    if not result.empty:
        row = result.iloc[0]
        details = {
            "reviewid": row['reviewid'],
            "album": row['title'],
            "score": row['score'],
            "artist": row['artist']
        }
        return details
    else:
        return {}
    
def get_reviewid_from_custom_id(custom_id:str):
    return custom_id.split('_')[0]

# %% [markdown]
# # Prompt Generator
#
# Here we create a prompt with the context gathered through the different data operations.

# %%
chroma = chromadb.HttpClient(host=vector_db_client_url)
collection = chroma.get_collection(name="pitchfork_reviews", 
                                   embedding_function=OpenAIEmbeddingFunction(
                                       api_key = os.getenv("OPENAI_API_KEY"),
                                       model_name="text-embedding-3-small")
                                   )

# %%
collection.query(
    query_texts=["A great album with stunning vocals and production."],
    n_results=3
)
# Out:
# {'ids': [['398_15632_1801', '4428_16669_1802', '6881_16771_3609']],
#  'distances': [[1.0196459, 1.0360501, 1.036174]],
#  'embeddings': None,
#  'metadatas': [[None, None, None]],
#  'documents': [['vocals take on an even more tranquil quality than previous offerings, just begging to grace     a pair of headphones.  In fact, the subtle variations in vocal renderings between the three songs are the     only true variants within the album, which follows logically given no-one has any misconceptions about     where Azure Ray\'s bread is buttered.          "The Love of Two", the only non-album track, is the most atmospheric, as well as most memorable.  An     incessant vinyl scratch murmurs beneath a subtle vocal tonality reminiscent of Mazzy Star, which, distant     and haunted, provides an excellent equipoise to the visceral production.  A "Bleed Version" of the     album-inclusive "We Are Mice" rounds out the disc with sparse piano backing and choral vocals that I     swear could only be described as uncannily Sarah McLachlan-esque.  There are no true departures to be     found, merely minor tweaking. Unfortunately, the lyrics still read a bit much like Felicity\'s diary,     but such a regrettable lyrical acumen can easily be overlooked; this music is tactile at heart. If     the duo can simply up the cerebral factor and maybe add a little spice to the mix, a real statement     could be served up.',
#    'Though most of the tracks have vocals, Renn\'s voice is buried by the mix.  And while this kind of     indistinct singing may be a legitimate shoe-mo tactic, it doesn\'t make the album any stronger.          The subtle melodies only occasionally break out of the clouds, and the shambling performance that sounds so     fresh on the \'big\' numbers can turn into sludge on the slower ones; and with so many rich instrumentals,     quaint songs like "The Only Good Thing About Pollution" just drift off into space.  Which is a shame,     because stronger writing could have made this a gripping record, and not just a gorgeous one.',
#    '"Thanks Just the Same" is a gorgeous ballad filled with floating piano figures, dejected     vocals, and yep, tons more distortion.  The guitar loses prominence as the song progresses,     setting up the off-kilter "Nothing Can Make Me Feel Better," which opens relatively clean     over some drunken piano before the static undertow and frantically busy drum program cut in.     The album closes with "It\'s Been Worth the Wait," and you\'re likely to agree, because it\'s     the most majestic track on the album, weaving synth and distorted guitar (of course) into a     quilt of pure sound and bringing the album full circle to the sound that opens it.          One thing I love to do with records that feel this complete is try to divide them into     logical, equal sections, and I find that it\'s usually possible on some level.  Whatever     It Meant follows what I\'ve found to be a broad trend of breaking works into thirds to     make them more digestible.  You\'ve got the noisy/melodic first-third, the relatively clean,     more sonically varied second-third, and the noisy/melodic/this-time-with-piano final third,     complete with a nod back to the beginning at the end.  It sounds simple, but it\'s this kind     of logical flow that makes this album a breeze to listen to, despite its often challenging     mix. Whatever It Meant is an intriguing solo debut for an artist who\'s obviously not afraid     to try something different.  Aside from his sonic adventurousness, though, he\'s also got an     innate pop sense to balance it with, and that\'s what really makes it work.  This album is a     world of sound, and it\'s got the hooks to drag you right into it.  Give it a try.']],
#  'uris': None,
#  'data': None,
#  'included': ['metadatas', 'documents', 'distances']}

# %%
def get_context_data(query:str, collection:chromadb.api.models.Collection, top_n:int):
    results = collection.query(
        query_texts=[query],
        n_results=top_n
    )
    context_data = []
    for idx, custom_id in enumerate(results['ids'][0]):
        review_id = get_reviewid_from_custom_id(custom_id)
        details = additional_details(review_id)
        details['text'] = results['documents'][0][idx]
        context_data.append(details)
    return context_data

def generate_prompt(query:str, collection:chromadb.api.models.Collection, top_n:int):
    context_data = get_context_data(query, collection, top_n)
    prompt = f"Given a query, provide a detailed response using the context from relevant Pitchfork reviews. The context will contain references to {top_n} album reviews.\n\n"
    prompt += f"The score is numeric and its scale is from 0 to 10, with 10 being the highest rating. Any album with a score greater than 8.0 is considered a must-listen; album with a score greater than 6.5 is good.\n\n"
    prompt += f"<query>{query}</query>\n\n"
    prompt += "<context>\n"
    for k, context in enumerate(context_data):
        prompt += f"<album {k}>\n"
        prompt += f"- Album Title: {context.get('album', 'N/A')}\n" 
        prompt += f"- Album Artist: {context.get('artist', 'N/A')}\n"
        prompt += f"- Album Score: {context.get('score', 'N/A')}\n"
        prompt += f"- Review Quote: {context.get('text', 'N/A')}\n"
        prompt += f"</album {k}>\n\n"
    prompt += "</context>\n\n"
    prompt += "\nBased on the context and nothing else, provide a detailed response to the query."
    return prompt

def generate_response(query:str, collection:chromadb.api.models.Collection, top_n:int=1):
    prompt = generate_prompt(query, collection, top_n)
    print("Generated Prompt:\n", prompt)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful assistant that provides information based on Pitchfork reviews."},
            {"role": "user", "content": prompt}
        ],
        max_tokens=500,
        temperature=0.7
    )
    return response.choices[0].message.content

# %% [markdown]
# # Query
#
# We can now use chroma's similarity function to query the database. Notice that the query itself needs to be converted to embeddings, so we must provide an `embedding_function`. In this case, we use `OpenAIEmbeddingFunction()` to get compatible embeddings using model `text-embedding-3-small`.

# %%
response = generate_response("What are some highly rated albums by emerging indie artists?", collection, 3)
# Out:
# Generated Prompt:
#  Given a query, provide a detailed response using the context from relevant Pitchfork reviews. The context will contain references to 3 album reviews.
#
# The score is numeric and its scale is from 0 to 10, with 10 being the highest rating. Any album with a score greater than 8.0 is considered a must-listen; album with a score greater than 6.5 is good.
#
# <query>What are some highly rated albums by emerging indie artists?</query>
#
# <context>
# <album 0>
# - Album Title: conductor
# - Album Artist: the comas
# - Album Score: 8.0
# - Review Quote: At the heart of the indie mindset is a profound disconnect between perception and actuality.  The ideal:     D.I.Y. ethics, an emphasis on art above marketability, and a purity of purpose that is resistant to fads and     monetary influence.  The reality: indie bands are receiving six-digit recording advances from major media     conglomerates, and are just as ripe for demographic targeting, strategic media placement, and lifestyle     branding as "mainstream" bands.  Indie groups like The Shins, Death Cab for Cutie and Modest Mouse can be     heard on teen dramas, late-night talk shows, and in Target, automobile and fast-food television spots.          More power to them.  I don't posit that the increasing permeability of the membrane between indie and     mainstream is an insidious development; instead, it should be acknowledged in the interest of foiling     nonsensical Puritanism.  While truly market-exempt, homegrown music exists (let's call it indie with a     lowercase "i"), it's undeniable that capital-I Indie Music (i.e. music aimed at the charts that is "indie"     only in its external mien) is here.  Indie Music is big business, and it's absurd to act like it's still     being run out of someone's garage.  The central paradox is that Indie Bands are marketed as personal     choices that express the consumer's highly specific personality and separation from the herd by grouping     them within, natch, one large and faceless herd-- at least Avril Lavigne makes no bones about being for     the masses.          Enter The Comas, who tread this imbricate middle ground between indie and mainstream.  Teen dramas on the     WB have become a fertile market for Indie Music song placement.  Comas singer Andy Herod has done Death     Cab and The Shins one better by dating Dawson's Creek's Michelle Williams for a couple years, then     writing an album about the relationship and its demise.  Conductor was at least partially banked by     Warner Bros., who released it
# </album 0>
#
# <album 1>
# - Album Title: espers
# - Album Artist: espers
# - Album Score: 8.4
# - Review Quote: Maybe it was when Nick Drake's "Pink Moon" inexplicably came beaming out of television sets far and wide     selling Volkswagens, but there's been a disproportionate amount of interest lately surrounding the enigmatic     canon of folk music from the late 60s and early 70s.  As reverently packaged reissues from treasured     shoulda-been folk legends like Karen Dalton, Jackson C. Frank, Dando Shaft, Linda Perhacs and established     revivalist heroes such as Bert Jansch and Pentangle, Fred Neil, John Fahey, and Fairport Convention seemed     to take up increasing amount of space in my CD changer, a slew of indie-bred legionnaires (Devendra Banhart,     Iron & Wine, Animal Collective, Sufjan Stevens, Currituck Co, etc) seemed hard at work setting out to     passionately revive the folk revival in their own wildly idiosyncratic ways.          For anyone who's seen so much as the album insert for any of these treasured older records, it makes sense     that the indie community would fall head over heels for the Folk aesthetic; Bert Jansch looks like Stephen     Malkmus' more literal twin, while Fairport Convention, covered in all things involving facial hair, Converse     and corduroy, bear an uncanny resemblance to the incestuous communal trappings of the indie-royalty of     Elephant 6.  The postmodern landscape successfully tread by the likes of the White Stripes, The Strokes,     The Rapture, and (The) Ryan Adams has arguably put a price-tag on the bourgeois "cleverness" of miming     critical approved "tastes" from lost eras; a renewed interest in folk music's reliance on song rather than     sound seems only natural.          Thankfully, Greg Weeks' steady stream of neo-folk records (culminating in 2001's landmark Awake Like     Sleep and 2003's more esoteric, Slightly West) has been supplying listeners with a lush blend     of psych-charged melancholia (a la Nico) and kaleidoscopic drones while always retaining beautifully     baroque melodies as their focal
# </album 1>
#
# <album 2>
# - Album Title: electric pink ep
# - Album Artist: the promise ring
# - Album Score: 0.7
# - Review Quote: this the best     independent music has to offer?  If indie rock has come to slowed-down,     pillowfight pop-punk, punch me out.  Attached you will find a list of 457 bands     I recommend over this release.  If you're such a fan, you're welcome to change     your name to 'Electric Pink,' open up a weblog titled Electricpink.org, and     praise this record's merits.  People can call you 'Pinky!'  I won't be visiting."
# </album 2>
#
# </context>
#
#
# Based on the context and nothing else, provide a detailed response to the query.

# %%
print(response)
# Out:
# If you’re looking for highly rated albums by emerging indie artists, there are a couple that stand out based on recent Pitchfork reviews.
#
# 1. **Espers - *Espers*** (Score: 8.4)
#    This self-titled album from the band Espers is a notable entry in the indie scene, particularly for its homage to the folk music of the late 60s and early 70s. The review highlights a resurgence of interest in folk aesthetics within the indie community, with Espers contributing a lush blend of psych-infused melancholia and beautifully baroque melodies. Their sound reflects a deep connection to the folk revival, showcasing a refreshing take that resonates with both old and new listeners. This album is highly recommended for anyone interested in the current wave of folk-inspired indie music.
#
# 2. **The Comas - *Conductor*** (Score: 8.0)
#    The Comas offer a unique perspective on the indie music landscape with *Conductor*, navigating the often complex relationship between indie and mainstream music. The review discusses the band’s ability to straddle this line effectively, making their music both personal and relatable, while also being commercially viable. The album is partly underpinned by the experiences of lead singer Andy Herod, who draws from his personal life, resulting in an authentic and engaging listening experience. This makes *Conductor* a must-listen for fans of indie rock that embraces both artistic integrity and broader appeal.
#
# While the *Electric Pink EP* by The Promise Ring received a significantly lower score (0.7), it serves as a reminder that not all indie releases resonate well with critics. However, the two albums mentioned above are excellent representations of the emerging indie scene, each offering a distinct sound and perspective worth exploring.

# %% [markdown]
# **Note**: Try changing the top_n parameter to 1 and re-run the query.
